# %% [markdown]
# <a href="https://colab.research.google.com/github/arafat-305047/B9-A1/blob/main/First_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lecture_1: First Python Program

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello! My name is Arafat. Welcome to post-graduate class of 2026")
# Out:
# Hello! My name is Arafat. Welcome to post-graduate class of 2026

# %% [markdown]
# Variables

# %%
a="cat"
b="dog"
c="duck"
print(a,b,c)
# Out:
# cat dog duck

# %%
name="arafat"
age=25
cgpa=3.86
print(name,age,cgpa)
# Out:
# arafat 25 3.86

# %% [markdown]
# Data Types

# %%
name="arafat"
age=25
height= 5.5
is_student = True
print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
a="that's my name"
print(a)
# Out:
# that's my name

# %%
first_name="arafat"
last_name="kabir"
full_name=first_name+" "+last_name
print(full_name)
# Out:
# arafat kabir

# %% [markdown]
# Data type identification

# %%
a="arafat"
b=25
c= 5.5
d=4+5j
is_student = True
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>

# %% [markdown]
# Data type conversion

# %%
a=5
b= 5.5
c=4+5j
print(float(a))
print(int(b))
print(complex(a))
print(complex(b))
# Out:
# 5.0
# 5
# (5+0j)
# (5.5+0j)

# %% [markdown]
# Number conversion

# %%
a=5
b="5"
print(a+int(b))
# Out:
# 10

# %%
#slicing string

a="hello world"
